# %%
# %pylab inline 
#import matplotlib or from matplotlib import *
import numpy as np
import string
from datascience import *
# Out:
# Populating the interactive namespace from numpy and matplotlib
# WARNING: pylab import has clobbered these variables: ['DateFormatter', 'percentile', 'Circle', 'Formatter']
# `%matplotlib` prevents importing * from pylab and numpy

# %%
# spalding = Table.read_table('spalding.txt')
    
with open('spalding.txt') as file_in:
    spalding = file_in.read()
spalding_list = spalding.split('\n'*2)

# def split_by_line(passage):
#     return passage.split('\u2028')

# spalding_list_detailed = [split_by_line(poem) for poem in spalding_list]
# spalding_list_detailed

# spalding_tokens = spalding_string.split()

# spalding_string = spalding_string.lower() #make all lowercase
# spalding_tokens = "".join([char for char in spalding_string if char not in string.punctuation]).split() 
# #don't have any more punctuation

# from collections import Counter
# spalding_dict = Counter(spalding_tokens) 

# spalding_dict
# Out:
# ['Canto the First. ‘The Spleen’',
#  'I\n“My uncle’s goodness is extreme,\u2028If seriously he hath disease;\u2028He hath acquired the world’s esteem\u2028And nothing more important sees;\u2028A paragon of virtue he!\u2028But what a nuisance it will be,\u2028Chained to his bedside night and day\u2028Without a chance to slip away.\u2028Ye need dissimulation base\u2028A dying man with art to soothe,\u2028Beneath his head the pillow smooth,\u2028And physic bring with mournful face,\u2028To sigh and meditate alone:\u2028When will the devil take his own!”',
# ...

# %%
johnston = Table.read_table('johnston.txt')
johnston
# Out:
# Chapter One
# I
# ``My uncle -- high ideals inspire him;
# but when past joking he fell sick,
# he really forced one to admire him --
# and never played a shrewder trick.
# Let others learn from his example!
# But God, how deadly dull to sample
# sickroom attendance night and day
# and never stir a foot away!
# And the sly baseness, fit to throttle,
# ... (5690 rows omitted)
